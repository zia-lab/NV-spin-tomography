# %%
import numpy as np
import matplotlib as mpl; import matplotlib.pyplot as plt
# %matplotlib inline
import os; import pickle

# %%
diccionario = {}

# %%
diccionario[(1)] = [(1,2,3)]

# %%
diccionario[(1)] += [(4,5,6)]

# %%
diccionario[(1)]
# Out:
# [(1, 2, 3), (4, 5, 6)]

# %%
_ , _ = 1, 2

# %%
_
# Out:
# 2

# %%
# %store -r spin_dict

# %%
len(measure_dii)
# Out:
# 406

# %%
(4072, 0.08491087238285977, 0.13134579883406267) in spin_dict
# Out:
# True

# %%
type(spin_dict)
# Out:
# dict

# %%
spin_dict[(4072, 0.08491087238285977, 0.13134579883406267)]
# Out:
# [(-615959.78295870451, 88218.50852706033, -0.99639723727292306),
#  (-270341.39856903488, 79063.33704256604, -0.99639723727292306),
#  (75276.985820631031, 69908.165557854532, -0.99639723727292306),
#  (420895.37021029927, 60752.994073298047, -0.99639723727292306),
#  (766513.75459996448, 51597.822588590512, -0.99639723727292306),
#  (-624886.91911972128, 92207.27034714981, -0.99639723727292306),
#  (-279279.03259035014, 82664.023429139532, -0.99639723727292306),
#  (66328.853939019144, 73120.776511081116, -0.99639723727292306),
#  (411936.74046838935, 63577.529593046755, -0.99639723727292306),
#  (757544.6269977591, 54034.282675004535, -0.99639723727292306)]

# %%
spin_dict.keys()
# Out:
# [(4072, 0.08491087238285977, 0.13134579883406267),
#  (3438, 0.056696555286695725, 0.5099167646530216),
#  (3951, 0.046056313382730342, 1.9485457873107157),
#  (4208, 0.018148561765081055, 0.011569356274535678),
#  (4424, 0.035655949433864492, 0.024752041089014867),
#  (4083, 0.056729302785149018, 0.021958452048869388),
#  (3674, 3.0644373166593364, 0.3153728527352736),
#  (4247, 1.2535425471917021, 0.02035733356998836),
#  (3478, 1.4989092457137563, 0.01208403646443354),
#  (3265, 1.2404765659524739, 0.15812777005194001),
#  (4860, 0.23509846994488415, 0.052074764300781673),
#  (4420, 0.044848233844108291, 0.051105012193805401),
#  (4497, 0.041677337408070801, 0.045422296142899575),
#  (3885, 0.13377988563839732, 0.94090977924516139),
#  (3372, 1.272676190082906, 0.093944807849520875),
#  (4208, 0.042389587964503865, 0.010154202730864238),
#  (3640, 0.045004549558673654, 0.062410074126003724),
#  (3415, 1.4880469422339713, 0.064885296350374932),
# ...

# %%
def isodd(x):
    if x%2 == 1:
        return True
    else:
        return False

# %%
filter(lambda i: i % 2, range(10))
# Out:
# [1, 3, 5, 7, 9]
